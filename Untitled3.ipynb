# %%
import numpy as np

# %%
f = np.load('first_graph.npy')

# %%
s = np.load('second_graph.npy')

# %%
from metrics import metrics

# %%
m = metrics(f,s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c4fcbaf2e96c> in <module>
# ----> 1 m = metrics(f,s)
#
# NameError: name 'metrics' is not defined

# %%
m.visual()
